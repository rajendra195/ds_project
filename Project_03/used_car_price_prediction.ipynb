# %% [markdown]
# # Packages and Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gdown

# %% [markdown]
# # Data Ingestion

# %%
# Loading datasets using pandas read_csv method to create a DataFrame
# dataset_url = "https://drive.google.com/u/1/uc?id=1YOloeZusq2PDuZq2Yc5FEnHEzahXa4xT&export=download"
# filename = "autos.csv"
# gdown.download(dataset_url, filename)
# df = pd.read_csv(filename)
# df.head(5)

# %%
# using pandas read csv
df = pd.read_csv("/media/rajendra_/A0A80645A8061A84/Data science/Project/Project_03/autos.csv")
df.head()
# Out:
#    index          dateCrawled                            name  seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   offerType  price abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    model kilometer  monthOfRegistration  fuelType       brand  \
# 0   golf    150000                    0    benzin  volkswagen
# 1    NaN    125000                    5    diesel        audi
# 2  grand    125000                    8    diesel        jeep
# 3   golf    150000                    6    benzin  volkswagen
# 4  fabia     90000                    7    diesel       skoda
#
#   notRepairedDamage          dateCreated nrOfPictures  postalCode  \
# 0               NaN  2016-03-24 00:00:00            0       70435
# 1                ja  2016-03-24 00:00:00            0       66954
# 2               NaN  2016-03-14 00:00:00            0       90480
# 3              nein  2016-03-17 00:00:00            0       91074
# 4              nein  2016-03-31 00:00:00            0       60437
#
#               lastSeen
# 0  2016-04-07 03:16:57
# 1  2016-04-07 01:46:50
# 2  2016-04-05 12:47:46
# 3  2016-03-17 17:40:17
# 4  2016-04-06 10:17:21
#
# [5 rows x 21 columns]

# %% [markdown]
# #### About Datasets
# The autos.csv dataset is a comprehensive collection of valuable data about used cars, and provides insight into how the cars are being sold, what price they are being sold for, and all the details about their condition. Each ad contains information such as dateCrawled (the date the ad was first seen), name of the car, seller type (private or dealer), offer type, price, A/B testing information , vehicle type, year of registration (at which year was the car first registered) , gearbox type, power output in PS (horsepower) , model of car , howmany kilometers has it driven so far , monthof registration(when it was first registered)(essentially giving us an idea about its age), fueltype utilized by it( petrol/diesel /electricity/lpg etc.), brand name to which it belongs to  notRepairedDamage - if there is any damage on the vehicle that has not been repaired yet. DateCreated gives us information when this particular advertisement was created in ebay or other place where these cars can be posted. The nrofpictures field will give you an estimate regarding how many images have been included with this ad and postalcode contain info regarding area code where car have been posted.. Lastly lastseen give us time estimation when a crawler last scan this particular post online .All these factors are instrumental in determining a suitable price for used vehicles . Meanwhile regression analysis based on average prices related to years can be done from this dataset .

# %% [markdown]
# # Data Profiling

# %%
# First five rows of the DataFrame
df.head()
# Out:
#    index          dateCrawled                            name  seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   offerType  price abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    model kilometer  monthOfRegistration  fuelType       brand  \
# 0   golf    150000                    0    benzin  volkswagen
# 1    NaN    125000                    5    diesel        audi
# 2  grand    125000                    8    diesel        jeep
# 3   golf    150000                    6    benzin  volkswagen
# 4  fabia     90000                    7    diesel       skoda
#
#   notRepairedDamage          dateCreated nrOfPictures  postalCode  \
# 0               NaN  2016-03-24 00:00:00            0       70435
# 1                ja  2016-03-24 00:00:00            0       66954
# 2               NaN  2016-03-14 00:00:00            0       90480
# 3              nein  2016-03-17 00:00:00            0       91074
# 4              nein  2016-03-31 00:00:00            0       60437
#
#               lastSeen
# 0  2016-04-07 03:16:57
# 1  2016-04-07 01:46:50
# 2  2016-04-05 12:47:46
# 3  2016-03-17 17:40:17
# 4  2016-04-06 10:17:21
#
# [5 rows x 21 columns]

# %% [markdown]
# #### All Columns:<br>
# `dateCrawled`: Date the car was crawled. (Date)<br>
# `name`: Name of the car. (String)<br>
# `seller`: Type of seller (private or dealer). (String)<br>
# `offerType`: Type of offer (e.g. sale, repair, etc.). (String)<br>
# `price`: Price of the car. (Integer)<br>
# `abtest`: Test type (A or B). (String)<br>
# `vehicleType`: Type of vehicle (e.g. SUV, sedan, etc.). (String)<br>
# `yearOfRegistration`: Year the car was registered. (Integer)<br>
# `gearbox`: Type of gearbox (manual or automatic). (String)<br>
# `powerPS`: Power of the car in PS. (Integer)<br>
# `model`: Model of the car. (String)<br>
# `kilometer`: Kilometers the car has been driven. (Integer)<br>
# `monthOfRegistration`: Month the car was registered. (Integer)<br>
# `fuelType`: Type of fuel (e.g. diesel, petrol, etc.). (String)<br>
# `brand`: Brand of the car. (String)<br>
# `notRepairedDamage`: Whether or not the car has any damage that has not been repaired. (String)<br>
# `dateCreated`: Date the car was created. (Date)<br>
# `nrOfPictures`: Number of pictures of the car. (Integer)<br>
# `postalCode`: Postal code of the car. (Integer)<br>
# `lastSeen`: Date the car was last seen. (Date)<br>

# %%
# Shape of the datasets/ DataFrame
df.shape
# Out:
# (371528, 21)

# %% [markdown]
# Datasets contains,
# * `3,71,528` number of rows
# * `21` number of columns

# %%
# name of all the columns
df.columns
# Out:
# Index(['index', 'dateCrawled', 'name', 'seller', 'offerType', 'price',
#        'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS',
#        'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# Above information shows all the `columns` name of the datasets.

# %%
# checking the data types of the columns in the DataFrame
df.dtypes
# Out:
# index                   int64
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %% [markdown]
# Datatypes of all the `columns` in the datasets are either `int` or `object`.

# %%
# .info() gives overall information of the datasets like columns, rows, datatypes, null values, etc.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                371528 non-null  int64
#  1   dateCrawled          371528 non-null  object
#  2   name                 371528 non-null  object
#  3   seller               371528 non-null  object
#  4   offerType            371528 non-null  object
#  5   price                371528 non-null  int64
#  6   abtest               371528 non-null  object
#  7   vehicleType          333659 non-null  object
#  8   yearOfRegistration   371528 non-null  int64
#  9   gearbox              351319 non-null  object
#  10  powerPS              371528 non-null  int64
#  11  model                351044 non-null  object
#  12  kilometer            371528 non-null  int64
#  13  monthOfRegistration  371528 non-null  int64
#  14  fuelType             338142 non-null  object
#  15  brand                371528 non-null  object
#  16  notRepairedDamage    299468 non-null  object
#  17  dateCreated          371528 non-null  object
#  18  nrOfPictures         371528 non-null  int64
#  19  postalCode           371528 non-null  int64
#  20  lastSeen             371528 non-null  object
# dtypes: int64(8), object(13)
# memory usage: 59.5+ MB

# %% [markdown]
# With above information we can see total number of `rows`, `columns` of the datasets, `not null` values<br>
# and `dtypes` of each `columns` and `memory usage` by the datasets.

# %%
# gives true false values if data in datasets are null it returns True else False.
df.isna()
# Out:
#         index  dateCrawled   name  seller  offerType  price  abtest  \
# 0       False        False  False   False      False  False   False
# 1       False        False  False   False      False  False   False
# 2       False        False  False   False      False  False   False
# 3       False        False  False   False      False  False   False
# 4       False        False  False   False      False  False   False
# ...       ...          ...    ...     ...        ...    ...     ...
# 371523  False        False  False   False      False  False   False
# 371524  False        False  False   False      False  False   False
# 371525  False        False  False   False      False  False   False
# 371526  False        False  False   False      False  False   False
# 371527  False        False  False   False      False  False   False
#
#         vehicleType  yearOfRegistration  gearbox  ...  model  kilometer  \
# 0              True               False    False  ...  False      False
# 1             False               False    False  ...   True      False
# 2             False               False    False  ...  False      False
# 3             False               False    False  ...  False      False
# 4             False               False    False  ...  False      False
# ...             ...                 ...      ...  ...    ...        ...
# 371523         True               False     True  ...   True      False
# 371524        False               False    False  ...  False      False
# 371525        False               False    False  ...  False      False
# 371526        False               False    False  ...  False      False
# 371527        False               False    False  ...  False      False
#
#         monthOfRegistration  fuelType  brand  notRepairedDamage  dateCreated  \
# 0                     False     False  False               True        False
# 1                     False     False  False              False        False
# 2                     False     False  False               True        False
# 3                     False     False  False              False        False
# 4                     False     False  False              False        False
# ...                     ...       ...    ...                ...          ...
# 371523                False      True  False               True        False
# 371524                False     False  False              False        False
# 371525                False     False  False              False        False
# 371526                False     False  False               True        False
# 371527                False     False  False              False        False
#
#         nrOfPictures  postalCode  lastSeen
# 0              False       False     False
# 1              False       False     False
# 2              False       False     False
# 3              False       False     False
# 4              False       False     False
# ...              ...         ...       ...
# 371523         False       False     False
# 371524         False       False     False
# 371525         False       False     False
# 371526         False       False     False
# 371527         False       False     False
#
# [371528 rows x 21 columns]

# %% [markdown]
# We can see the True and False value using isna() method.

# %%
# returns sum of the columns
df.isna().sum(axis=0)
# Out:
# index                      0
# dateCrawled                0
# name                       0
# seller                     0
# offerType                  0
# price                      0
# abtest                     0
# vehicleType            37869
# yearOfRegistration         0
# gearbox                20209
# powerPS                    0
# model                  20484
# kilometer                  0
# monthOfRegistration        0
# fuelType               33386
# brand                      0
# notRepairedDamage      72060
# dateCreated                0
# nrOfPictures               0
# postalCode                 0
# lastSeen                   0
# dtype: int64

# %% [markdown]
# In above information,<br>
# `vehicleType` contains 37869 missing values.<br>
# `gearbox` contains 20209 missing values.<br>
# `model` contains 20484 missing values.<br>
# `fuelType` contains 33386 missing values.<br>
# `notRepairedDamage` columns contains 72060 missing values.<br>
# and all the other columns doesn't contains missing values.

# %%
# returns null value percentage
df.isna().sum() / len(df) # total_null_sum / len_df
# Out:
# index                  0.000000
# dateCrawled            0.000000
# name                   0.000000
# seller                 0.000000
# offerType              0.000000
# price                  0.000000
# abtest                 0.000000
# vehicleType            0.101928
# yearOfRegistration     0.000000
# gearbox                0.054394
# powerPS                0.000000
# model                  0.055134
# kilometer              0.000000
# monthOfRegistration    0.000000
# fuelType               0.089861
# brand                  0.000000
# notRepairedDamage      0.193956
# dateCreated            0.000000
# nrOfPictures           0.000000
# postalCode             0.000000
# lastSeen               0.000000
# dtype: float64

# %% [markdown]
# In above information,<br>
# `vehicleType` contains `0.101%` missing values.<br>
# `gearbox` contains `0.054%` missing values.<br>
# `model` contains `0.055%` missing values.<br>
# `fuelType` contains `0.089%` missing values.<br>
# `notRepairedDamage` contains `0.19%` missing values.<br>

# %%
# descriptive statistics of integer columns
df.describe(include="int")
# Out:
#                index         price  yearOfRegistration        powerPS  \
# count  371528.000000  3.715280e+05       371528.000000  371528.000000
# mean   185763.500000  1.729514e+04         2004.577997     115.549477
# std    107251.039743  3.587954e+06           92.866598     192.139578
# min         0.000000  0.000000e+00         1000.000000       0.000000
# 25%     92881.750000  1.150000e+03         1999.000000      70.000000
# 50%    185763.500000  2.950000e+03         2003.000000     105.000000
# 75%    278645.250000  7.200000e+03         2008.000000     150.000000
# max    371527.000000  2.147484e+09         9999.000000   20000.000000
#
#            kilometer  monthOfRegistration  nrOfPictures    postalCode
# count  371528.000000        371528.000000      371528.0  371528.00000
# mean   125618.688228             5.734445           0.0   50820.66764
# std     40112.337051             3.712412           0.0   25799.08247
# min      5000.000000             0.000000           0.0    1067.00000
# 25%    125000.000000             3.000000           0.0   30459.00000
# 50%    150000.000000             6.000000           0.0   49610.00000
# 75%    150000.000000             9.000000           0.0   71546.00000
# max    150000.000000            12.000000           0.0   99998.00000

# %% [markdown]
# Using `.describe()` method we get, `count`, `mean`, `standard deviation`, `first quartile`, `median`, `third quartile` and `max_value` of each columns of numerical datatypes in the datasets.<br>
# * In `yearOfRegistration` column, count is `371528`, mean is `2004.58`, standard deviation is `92.86`, min value is `1000`, first quartile is `1999`, median is `2003`, third quartile is `2008` and max value is `9999`.<br>
# * Similarly, each columns has it's own values.

# %%
# descriptive statistics of object
df.describe(include="object")
# Out:
#                 dateCrawled         name  seller offerType  abtest  \
# count                371528       371528  371528    371528  371528
# unique               280500       233531       2         2       2
# top     2016-03-24 14:49:47  Ford_Fiesta  privat   Angebot    test
# freq                      7          657  371525    371516  192585
#
#        vehicleType  gearbox   model fuelType       brand notRepairedDamage  \
# count       333659   351319  351044   338142      371528            299468
# unique           8        2     251        7          40                 2
# top      limousine  manuell    golf   benzin  volkswagen              nein
# freq         95894   274214   30070   223857       79640            263182
#
#                 dateCreated             lastSeen
# count                371528               371528
# unique                  114               182806
# top     2016-04-03 00:00:00  2016-04-07 06:45:59
# freq                  14450                   17

# %% [markdown]
# Using `.describe(include="object")` method we get descriptive statistics of categorical data like `count`, `unique_values`, `top_value`, and `frequency_count`.<br><br>
# In the seller column, count is `371528`, unique_value is `2`, top frequency is `privat` and frequency count of privat is `371525`.
# Similarly, each column of categorical data has its own count, unique values, top frequency and frequency counts.

# %%
df.head(2)
# Out:
#    index          dateCrawled                  name  seller offerType  price  \
# 0      0  2016-03-24 11:52:17            Golf_3_1.6  privat   Angebot    480
# 1      1  2016-03-24 10:58:45  A5_Sportback_2.7_Tdi  privat   Angebot  18300
#
#   abtest vehicleType  yearOfRegistration  gearbox  ...  model kilometer  \
# 0   test         NaN                1993  manuell  ...   golf    150000
# 1   test       coupe                2011  manuell  ...    NaN    125000
#
#    monthOfRegistration  fuelType       brand notRepairedDamage  \
# 0                    0    benzin  volkswagen               NaN
# 1                    5    diesel        audi                ja
#
#            dateCreated nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00            0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00            0       66954  2016-04-07 01:46:50
#
# [2 rows x 21 columns]

# %% [markdown]
# #### Let's check if there is duplicate rows in the datasets

# %%
# returns True, False if there is duplicate rows
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 371523    False
# 371524    False
# 371525    False
# 371526    False
# 371527    False
# Length: 371528, dtype: bool

# %%
# returns the sum of duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Since the sum of all the rows is 0, so the datasets doesn't contains duplicate rows.

# %% [markdown]
# #### Checking unique values in the datasets in categorical data

# %%
# unique values in the  column
columns = ["seller", "offerType", "abtest", "gearbox"]

for column in columns:
    unique_value = df[column].unique()
    print(f"Unique values in {column} column are: {unique_value}.")
# Out:
# Unique values in seller column are: ['privat' 'gewerblich'].
# Unique values in offerType column are: ['Angebot' 'Gesuch'].
# Unique values in abtest column are: ['test' 'control'].
# Unique values in gearbox column are: ['manuell' 'automatik' nan].

# %% [markdown]
# .unique() method gives the unique values in the columns.<br>
# Unique values in seller column are: `['privat' 'gewerblich']`.<br>
# Unique values in offerType column are: `['Angebot' 'Gesuch']`.<br>
# Unique values in abtest column are: `['test' 'control']`.<br>
# Unique values in gearbox column are: `['manuell' 'automatik' nan]`.

# %%
# Number of unique values in the  column

for column in columns:
    unique_value_count = df[column].nunique()
    print(f"Number of Unique values in {column} column are: {unique_value_count}.")
# Out:
# Number of Unique values in seller column are: 2.
# Number of Unique values in offerType column are: 2.
# Number of Unique values in abtest column are: 2.
# Number of Unique values in gearbox column are: 2.

# %% [markdown]
# .nuinque() method gives the number of unique values in the columns.<br>
# Number of unique values in the seller, offerType, abtest, gearbox columns are `2` each.

# %%
# correlation of numerica columns in the datasets
df.corr(numeric_only=True)
# Out:
#                         index     price  yearOfRegistration   powerPS  \
# index                1.000000 -0.000696           -0.000060  0.000769
# price               -0.000696  1.000000           -0.000182  0.006850
# yearOfRegistration  -0.000060 -0.000182            1.000000  0.000351
# powerPS              0.000769  0.006850            0.000351  1.000000
# kilometer            0.003625 -0.000635           -0.055319 -0.010738
# monthOfRegistration  0.000914 -0.002826           -0.011607  0.044358
# nrOfPictures              NaN       NaN                 NaN       NaN
# postalCode           0.000038 -0.003164           -0.001652  0.027113
#
#                      kilometer  monthOfRegistration  nrOfPictures  postalCode
# index                 0.003625             0.000914           NaN    0.000038
# price                -0.000635            -0.002826           NaN   -0.003164
# yearOfRegistration   -0.055319            -0.011607           NaN   -0.001652
# powerPS              -0.010738             0.044358           NaN    0.027113
# kilometer             1.000000             0.001838           NaN   -0.026694
# monthOfRegistration   0.001838             1.000000           NaN    0.014963
# nrOfPictures               NaN                  NaN           NaN         NaN
# postalCode           -0.026694             0.014963           NaN    1.000000

# %%
df.nrOfPictures
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 371523    0
# 371524    0
# 371525    0
# 371526    0
# 371527    0
# Name: nrOfPictures, Length: 371528, dtype: int64

# %%
df.nrOfPictures.sum()
# Out:
# 0

# %% [markdown]
# Here, every value in the `nrOfPictures` columns is 0. So we will remove the column later.

# %% [markdown]
# # Data Cleaning

# %%
df.columns
# Out:
# Index(['index', 'dateCrawled', 'name', 'seller', 'offerType', 'price',
#        'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS',
#        'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#          index          dateCrawled  \
# 331333  331333  2016-03-28 15:36:40
# 154004  154004  2016-03-16 13:25:25
# 221059  221059  2016-03-09 18:42:51
# 169426  169426  2016-03-31 13:59:02
# 336257  336257  2016-04-02 18:56:12
#
#                                                  name  seller offerType  \
# 331333                          Ford_Focus_Turnier_DI  privat   Angebot
# 154004               Golf_4_1_6l_TÜV_mit_Font_Schaden  privat   Angebot
# 221059  Top_Zustand_bmw_320i_Cabrio_original_Zustand.  privat   Angebot
# 169426                                 Volvo_V70_2.4D  privat   Angebot
# 336257                  Fiat_Ducato_11_2.3_JDT___81KW  privat   Angebot
#
#         price   abtest vehicleType  yearOfRegistration  gearbox  ...   model  \
# 331333   1000  control       kombi                2004  manuell  ...   focus
# 154004    600     test         NaN                2017  manuell  ...    golf
# 221059   2800     test      cabrio                1996  manuell  ...     3er
# 169426  14900  control       kombi                2009  manuell  ...     v70
# 336257   3250  control         NaN                2016  manuell  ...  ducato
#
#        kilometer  monthOfRegistration  fuelType       brand notRepairedDamage  \
# 331333    150000                    6    diesel        ford              nein
# 154004    150000                    8    benzin  volkswagen                ja
# 221059    150000                    7    benzin         bmw              nein
# 169426    150000                    4    diesel       volvo              nein
# 336257    150000                    6       NaN        fiat              nein
#
#                 dateCreated nrOfPictures  postalCode             lastSeen
# 331333  2016-03-28 00:00:00            0       32760  2016-03-31 23:46:00
# 154004  2016-03-16 00:00:00            0       56457  2016-03-26 10:46:26
# 221059  2016-03-09 00:00:00            0       44309  2016-03-12 18:45:48
# 169426  2016-03-31 00:00:00            0       25899  2016-04-06 06:45:05
# 336257  2016-04-02 00:00:00            0       35767  2016-04-06 10:16:37
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Removing the columns which are not useful
# We are aiming to predict the price of used cars, so we will remove the columns that do not influence the price.<br>
# `index`: This column is simply the row index.<br>
# `name`: This column  contain a string identifier for each row. It doesn't offer meaningful insights to Target variable.<br>
# `nrOfPictures`: All the values in the columns are 0 so we will remove it.<br>
# `postalCode`: The postal code provides information on geographic location, it may not directly afect target variable so we will remove it.<br>
# `dateCrawled`: The date when the data was crawled from the website does not relate directly to the car's price, so it can be removed.<br>
# `lastSeen`: The date when a listing was last seen online might not have a clear impact on the car's price and may be considered redundant.<br>
# `dateCreated`: The date the listing was created may not have a direct relationship with the car's price, making it less useful for prediction.<br>
# `model`: brand column is already in datasets

# %%
# columns that are to be removed
column_to_remove = ["index", "name", "nrOfPictures", "model", "postalCode", "dateCreated", "lastSeen", "dateCrawled"]

#dropping the columns
df.drop(column_to_remove, axis="columns", inplace=True)

# %%
df.head(2)
# Out:
#    seller offerType  price abtest vehicleType  yearOfRegistration  gearbox  \
# 0  privat   Angebot    480   test         NaN                1993  manuell
# 1  privat   Angebot  18300   test       coupe                2011  manuell
#
#    powerPS  kilometer  monthOfRegistration fuelType       brand  \
# 0        0     150000                    0   benzin  volkswagen
# 1      190     125000                    5   diesel        audi
#
#   notRepairedDamage
# 0               NaN
# 1                ja

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.head()
# Out:
#    seller offerType  price abtest vehicleType  yearOfRegistration    gearbox  \
# 0  privat   Angebot    480   test         NaN                1993    manuell
# 1  privat   Angebot  18300   test       coupe                2011    manuell
# 2  privat   Angebot   9800   test         suv                2004  automatik
# 3  privat   Angebot   1500   test  kleinwagen                2001    manuell
# 4  privat   Angebot   3600   test  kleinwagen                2008    manuell
#
#    powerPS  kilometer  monthOfRegistration fuelType       brand  \
# 0        0     150000                    0   benzin  volkswagen
# 1      190     125000                    5   diesel        audi
# 2      163     125000                    8   diesel        jeep
# 3       75     150000                    6   benzin  volkswagen
# 4       69      90000                    7   diesel       skoda
#
#   notRepairedDamage
# 0               NaN
# 1                ja
# 2               NaN
# 3              nein
# 4              nein

# %%
df.columns
# Out:
# Index(['seller', 'offerType', 'price', 'abtest', 'vehicleType',
#        'yearOfRegistration', 'gearbox', 'powerPS', 'kilometer',
#        'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage'],
#       dtype='object')

# %% [markdown]
# #### Univariate Analysis and visualization of distribution of categorical data

# %% [markdown]
# Function for univariate barplot

# %%
# function for univariate barplot
def univariate_barplot(data, column):

    # figure size of the barplot
    plt.figure(figsize=(10, 8))

    # value counts of the columns
    value = data[column].value_counts()

    # barplot using seaborn
    ax = value.plot.bar(x=value.index, y=value.values, color=sns.color_palette("hls"), rot=0)

    total_value = value.sum()

    for plot in ax.patches:
        # get height of each plot
        height = plot.get_height()

        # annote each plot
        ax.annotate(

            f"{height / total_value * 100:.2f}%",
            xy = (
                plot.get_x() + plot.get_width() / 2.,
                height
            ),
            ha = "center"
        )



    plt.ylabel("Frequency")
    plt.title(f"Distribution plot of {column} in the datasets")
    plt.show()

# %% [markdown]
# #### seller column

# %%
# value counts of seller column
df.seller.value_counts()
# Out:
# seller
# privat        371525
# gewerblich         3
# Name: count, dtype: int64

# %% [markdown]
# The seller column contains data on the type of seller, with 371,524 entries labeled as "privat" and only 3 entries labeled as "gewerblich". Since the vast majority of entries are of one type of seller (private), this column does not provide significant differentiation or insight for predicting the target variable (car price). Therefore, we will drop the seller column as it does not meaningfully impact the analysis.

# %%
# dropping seller columns
df.drop("seller", axis="columns", inplace=True)

# %%
df.head(2)
# Out:
#   offerType  price abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 0   Angebot    480   test         NaN                1993  manuell        0
# 1   Angebot  18300   test       coupe                2011  manuell      190
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja

# %% [markdown]
# #### offerType column

# %%
# value counts
df["offerType"].value_counts()
# Out:
# offerType
# Angebot    371516
# Gesuch         12
# Name: count, dtype: int64

# %% [markdown]
# The offerType column contains data with 371,516 rows labeled as "Angebot" and only 12 entries labeled as "Gesuch". Since the vast majority of entries are of one type of offerType (Angebot), this column does not provide significant differentiation or insight for predicting the target variable (car price). Therefore, we will drop the offerType column as it does not meaningfully impact the analysis.

# %%
# dropping the offerType column
df.drop("offerType", axis="columns", inplace=True)

# %%
df.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0    480   test         NaN                1993    manuell        0
# 1  18300   test       coupe                2011    manuell      190
# 2   9800   test         suv                2004  automatik      163
# 3   1500   test  kleinwagen                2001    manuell       75
# 4   3600   test  kleinwagen                2008    manuell       69
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein

# %% [markdown]
# #### abtest column

# %%
# value_counts
df["abtest"].value_counts()
# Out:
# abtest
# test       192585
# control    178943
# Name: count, dtype: int64

# %% [markdown]
# Abtest columns contains two types of abtest that is test and control.<br>
# * `192,585` entries are `test` type
# * `179,943` entries are `control` type

# %%
# barplot
univariate_barplot(data=df, column="abtest")

# %% [markdown]
# Above barplot shows,
# * `51.84%` of data are `test` type.
# * `48.16%` of data are `control` type abtest.

# %% [markdown]
# #### vehicleType column

# %%
# value counts
df["vehicleType"].value_counts()
# Out:
# vehicleType
# limousine     95894
# kleinwagen    80023
# kombi         67564
# bus           30201
# cabrio        22898
# coupe         19015
# suv           14707
# andere         3357
# Name: count, dtype: int64

# %% [markdown]
# vehicheType column contains 8 types of categorical data they are limousine, kleinwagen, kombi, bus, cabrio, coupe, suv and andere.
# * `95894` entries are `limousine` type.
# * `80023` entries are of `kleinwagen` type.
# * `67564` entries are of `kombi` type.
# * `30201` entries are of `bus` type.
# * `22898` entries are of `cabrio` type.
# * `19015` entries are of `coupe` type.
# * `14707` entries are of `suv` type.
# * `3357` enries are `andere` type.

# %%
# barplot
univariate_barplot(data=df, column="vehicleType")

# %% [markdown]
# Above barplot shows that
# * `28.74%` of data are `limousine` type.
# * `23.98%` of data are `kleinwagen` type.
# * `20.25%` of data are `kombi` type.
# * `9.05%` of data are  `bus` type.
# * `6.86%` of data are  `cabrio` type.
# * `5.70%` of data are  `coupe` type.
# * `4.41%` entries are  `suv` type.
# * `1.01%` of data are `andere` type.

# %% [markdown]
# #### gearbox column

# %%
# value counts
df.gearbox.value_counts()
# Out:
# gearbox
# manuell      274214
# automatik     77105
# Name: count, dtype: int64

# %%
# barplot
univariate_barplot(data=df, column="gearbox")

# %% [markdown]
# #### fuelType column

# %%
# valuecounts
df["fuelType"].value_counts()
# Out:
# fuelType
# benzin     223857
# diesel     107746
# lpg          5378
# cng           571
# hybrid        278
# andere        208
# elektro       104
# Name: count, dtype: int64

# %%
#barplot
univariate_barplot(data=df, column="fuelType")

# %% [markdown]
# #### nonRepairedDamage column

# %%
# valuecounts
df.notRepairedDamage.value_counts()
# Out:
# notRepairedDamage
# nein    263182
# ja       36286
# Name: count, dtype: int64

# %%
# barplot
univariate_barplot(data=df, column="notRepairedDamage")

# %% [markdown]
# #### brand column

# %%
# value counts
df.brand.value_counts()
# Out:
# brand
# volkswagen        79640
# bmw               40274
# opel              40136
# mercedes_benz     35309
# audi              32873
# ford              25573
# renault           17969
# peugeot           11027
# fiat               9676
# seat               7022
# mazda              5695
# skoda              5641
# smart              5249
# citroen            5182
# nissan             5037
# toyota             4694
# sonstige_autos     3982
# hyundai            3646
# mini               3394
# volvo              3327
# mitsubishi         3061
# honda              2836
# kia                2555
# alfa_romeo         2345
# suzuki             2328
# porsche            2215
# chevrolet          1845
# chrysler           1452
# dacia               900
# jeep                807
# daihatsu            806
# subaru              779
# land_rover          770
# jaguar              621
# trabant             591
# daewoo              542
# saab                530
# rover               490
# lancia              484
# lada                225
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    price abtest vehicleType  yearOfRegistration  gearbox  powerPS  kilometer  \
# 0    480   test         NaN                1993  manuell        0     150000
# 1  18300   test       coupe                2011  manuell      190     125000
#
#    monthOfRegistration fuelType       brand notRepairedDamage
# 0                    0   benzin  volkswagen               NaN
# 1                    5   diesel        audi                ja

# %%
univariate_barplot(data=df, column="fuelType")

# %% [markdown]
# #### categorical data with target variable

# %%
df.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage'],
#       dtype='object')

# %% [markdown]
# #### abtest vs price

# %%
sns.boxplot(data=df, x="abtest", y="price")
plt.show()

# %% [markdown]
# We have such figures due to huge outliers.

# %% [markdown]
# #### vehicleType vs price

# %%
sns.boxplot(data=df, x="vehicleType", y="price")
# Out:
# <Axes: xlabel='vehicleType', ylabel='price'>

# %% [markdown]
# #### Numerical data

# %%
df.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0    480   test         NaN                1993    manuell        0
# 1  18300   test       coupe                2011    manuell      190
# 2   9800   test         suv                2004  automatik      163
# 3   1500   test  kleinwagen                2001    manuell       75
# 4   3600   test  kleinwagen                2008    manuell       69
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein

# %%
sns.histplot(data=df, x="yearOfRegistration", kde=True)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='Count'>

# %% [markdown]
# # yearsOfRegistration column

# %%
sns.boxplot(df["yearOfRegistration"])
sns.stripplot(df["yearOfRegistration"])
# Out:
# <Axes: ylabel='yearOfRegistration'>

# %% [markdown]
# #### powerPS

# %%
sns.boxplot(df["powerPS"])
sns.stripplot(df["powerPS"])
# Out:
# <Axes: ylabel='powerPS'>

# %% [markdown]
# #### kilometer column

# %%
sns.boxplot(df["kilometer"])
sns.stripplot(df["kilometer"])
# Out:
# <Axes: ylabel='kilometer'>

# %%
sns.boxplot(df["price"])
sns.stripplot(df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df["monthOfRegistration"])
sns.stripplot(df["monthOfRegistration"])
# Out:
# <Axes: ylabel='monthOfRegistration'>

# %% [markdown]
# #### Handling missing values

# %%
df.isna().sum()
# Out:
# price                      0
# abtest                     0
# vehicleType            37869
# yearOfRegistration         0
# gearbox                20209
# powerPS                    0
# kilometer                  0
# monthOfRegistration        0
# fuelType               33386
# brand                      0
# notRepairedDamage      72060
# dtype: int64

# %% [markdown]
# #### since all the missing values are in categorical data we will fill the missing values using mode

# %%
vehicle_type = df.vehicleType.value_counts(ascending=False)
df["vehicleType"] = df["vehicleType"].fillna(vehicle_type.index[0])

# %%
gear_box = df.gearbox.value_counts(ascending=False)
df["gearbox"] = df["gearbox"].fillna(gear_box.index[0])

# %%
fuel_type = df.fuelType.value_counts(ascending=False)
df["fuelType"] = df["fuelType"].fillna(fuel_type.index[0])

# %%
not_damage = df.notRepairedDamage.value_counts(ascending=False)
df["notRepairedDamage"] = df["notRepairedDamage"].fillna(not_damage.index[0])

# %%
df.isna().sum()
# Out:
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dtype: int64

# %%
df.vehicleType.value_counts()
# Out:
# vehicleType
# limousine     133763
# kleinwagen     80023
# kombi          67564
# bus            30201
# cabrio         22898
# coupe          19015
# suv            14707
# andere          3357
# Name: count, dtype: int64

# %%
# df.loc[]

# %% [markdown]
# #### Handling outliers

# %%
def remove_outliers(df, column_name):

    # IQR
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # outliers threshold
    lower_fench = Q1 - 1.5 * IQR
    upper_fench = Q3 + 1.5 * IQR

    # removing outliers
    df_cleaned = df[(df[column_name] >= lower_fench) & (df[column_name] <= upper_fench)]

    # clean DataFrame
    return df_cleaned

# %%
clean_df = remove_outliers(df=df, column_name="price")

# %%
sns.boxplot(clean_df["price"])
sns.stripplot(clean_df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
clean_df = remove_outliers(df=clean_df, column_name="yearOfRegistration")

# %%
sns.boxplot(clean_df["yearOfRegistration"])
sns.stripplot(clean_df["yearOfRegistration"])
# Out:
# <Axes: ylabel='yearOfRegistration'>

# %%
clean_df = remove_outliers(df=clean_df, column_name="powerPS")

# %%
sns.boxplot(clean_df["powerPS"])
sns.stripplot(clean_df["powerPS"])
# Out:
# <Axes: ylabel='powerPS'>

# %% [markdown]
# #### distribution of numerical data

# %%
sns.histplot(clean_df["yearOfRegistration"], kde=True)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='Count'>

# %%
sns.histplot(clean_df["powerPS"], kde=True)
# Out:
# <Axes: xlabel='powerPS', ylabel='Count'>

# %%
sns.histplot(data=clean_df, x="kilometer", kde=True)
# Out:
# <Axes: xlabel='kilometer', ylabel='Count'>

# %%
sns.histplot(data=clean_df, x="monthOfRegistration", kde=True)
# Out:
# <Axes: xlabel='monthOfRegistration', ylabel='Count'>

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ##### Relation between seller and price

# %%
sns.boxplot(data=clean_df, x="abtest", y="price")
# Out:
# <Axes: xlabel='abtest', ylabel='price'>

# %% [markdown]
# #### vehicleType vs price

# %%
mean_prices = clean_df.groupby('vehicleType')['price'].mean().reset_index()

plt.figure(figsize=(12, 10))
sns.boxplot(data=clean_df, x="vehicleType", y="price")

for idx, label in enumerate(mean_prices['vehicleType']):
    mean_price = mean_prices.iloc[idx]['price']
    plt.text(idx, mean_price, f'{mean_price:.2f}', ha='center', va='bottom', color='r', fontsize=10)

plt.show()

# %% [markdown]
# ##### brand vs price

# %%
plt.figure(figsize=(14, 12))
sns.boxplot(data=clean_df, x="brand", y="price")
plt.xticks(rotation=45)
plt.show()

# %%
clean_df.kilometer.unique()
# Out:
# array([150000, 125000,  90000,  30000, 100000,  60000,  70000,  80000,
#          5000,  50000,  40000,  20000,  10000], dtype=int64)

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(data=clean_df, x="kilometer", y="price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### relation between numerical data vs target variable (price)

# %%
#### kilometer vs price

# %%
sns.scatterplot(data=clean_df, x="kilometer",  y="price")
plt.show()

# %% [markdown]
# #### yearOfRegistration vs price

# %%
sns.scatterplot(data=clean_df, x="yearOfRegistration", y="price")
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %% [markdown]
# #### powerPS vs price

# %%
sns.scatterplot(data=clean_df, x="powerPS", y="price")
plt.show()

# %% [markdown]
# #### monthOfRegistration vs price

# %%
sns.scatterplot(data=clean_df, x="monthOfRegistration", y="price")
# Out:
# <Axes: xlabel='monthOfRegistration', ylabel='price'>

# %%
clean_df.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage'],
#       dtype='object')

# %% [markdown]
# #### Target variable

# %%
sns.histplot(data=clean_df, x="price", kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
clean_df[["price", "yearOfRegistration", "powerPS", "kilometer", "monthOfRegistration"]].skew()
# Out:
# price                  1.306872
# yearOfRegistration     0.283519
# powerPS               -0.020512
# kilometer             -1.849496
# monthOfRegistration    0.080546
# dtype: float64

# %%
df.kilometer.skew()
# Out:
# -1.5515772692054193

# %%
clean_df.shape
# Out:
# (330381, 11)

# %%
clean_df.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage'],
#       dtype='object')

# %%
clean_df.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0    480   test   limousine                1993    manuell        0
# 2   9800   test         suv                2004  automatik      163
# 3   1500   test  kleinwagen                2001    manuell       75
# 4   3600   test  kleinwagen                2008    manuell       69
# 5    650   test   limousine                1995    manuell      102
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen              nein
# 2     125000                    8   diesel        jeep              nein
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
# 5     150000                   10   benzin         bmw                ja

# %%
df.corr(numeric_only=True)
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000           -0.000182  0.006850  -0.000635
# yearOfRegistration  -0.000182            1.000000  0.000351  -0.055319
# powerPS              0.006850            0.000351  1.000000  -0.010738
# kilometer           -0.000635           -0.055319 -0.010738   1.000000
# monthOfRegistration -0.002826           -0.011607  0.044358   0.001838
#
#                      monthOfRegistration
# price                          -0.002826
# yearOfRegistration             -0.011607
# powerPS                         0.044358
# kilometer                       0.001838
# monthOfRegistration             1.000000

# %%
df.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration
# count        371528.000000
# mean              5.734445
# std               3.712412
# min               0.000000
# 25%               3.000000
# 50%               6.000000
# 75%               9.000000
# max              12.000000

# %%
df.price.max()
# Out:
# 2147483647

# %%
df.groupby((df["price"] > 100000)).price.size()
# Out:
# price
# False    371125
# True        403
# Name: price, dtype: int64

# %%
# df.model.unique()

# %%
sns.boxplot(clean_df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
clean_df.describe()
# Out:
#                price  yearOfRegistration        powerPS      kilometer  \
# count  330381.000000       330381.000000  330381.000000  330381.000000
# mean     3874.552178         2003.411392     101.128228  129960.030995
# std      3768.428615            6.315505      55.325253   36308.090416
# min         0.000000         1987.000000       0.000000    5000.000000
# 25%      1000.000000         1999.000000      68.000000  125000.000000
# 50%      2500.000000         2003.000000     102.000000  150000.000000
# 75%      5666.000000         2007.000000     140.000000  150000.000000
# max     16270.000000         2019.000000     248.000000  150000.000000
#
#        monthOfRegistration
# count        330381.000000
# mean              5.716409
# std               3.731281
# min               0.000000
# 25%               3.000000
# 50%               6.000000
# 75%               9.000000
# max              12.000000

# %%
clean_df.vehicleType.value_counts()
# Out:
# vehicleType
# limousine     119198
# kleinwagen     78744
# kombi          61832
# bus            27399
# cabrio         17827
# coupe          13047
# suv             9404
# andere          2930
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
clean_df.reset_index(inplace=True, drop=True)

# %%
clean_df.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0    480   test   limousine                1993    manuell        0
# 1   9800   test         suv                2004  automatik      163
# 2   1500   test  kleinwagen                2001    manuell       75
# 3   3600   test  kleinwagen                2008    manuell       69
# 4    650   test   limousine                1995    manuell      102
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen              nein
# 1     125000                    8   diesel        jeep              nein
# 2     150000                    6   benzin  volkswagen              nein
# 3      90000                    7   diesel       skoda              nein
# 4     150000                   10   benzin         bmw                ja

# %%
categorical_data = ["abtest", "vehicleType", "gearbox", "fuelType", "brand", "notRepairedDamage"]

# %%
clean_df[categorical_data].head()
# Out:
#   abtest vehicleType    gearbox fuelType       brand notRepairedDamage
# 0   test   limousine    manuell   benzin  volkswagen              nein
# 1   test         suv  automatik   diesel        jeep              nein
# 2   test  kleinwagen    manuell   benzin  volkswagen              nein
# 3   test  kleinwagen    manuell   diesel       skoda              nein
# 4   test   limousine    manuell   benzin         bmw                ja

# %%
numerical_data = ["yearOfRegistration", "powerPS", "kilometer", "monthOfRegistration"]
clean_df[numerical_data].head()
target = clean_df["price"]
target
# Out:
# 0          480
# 1         9800
# 2         1500
# 3         3600
# 4          650
#           ...
# 330376       0
# 330377    2200
# 330378    1199
# 330379    9200
# 330380    3400
# Name: price, Length: 330381, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def func_label_encoder(column):
    label_enc = LabelEncoder()
    label_enc.fit(column)
    return label_enc

# %%
features_clean = clean_df[categorical_data + numerical_data]
features = features_clean.copy()
features.head()
# Out:
#   abtest vehicleType    gearbox fuelType       brand notRepairedDamage  \
# 0   test   limousine    manuell   benzin  volkswagen              nein
# 1   test         suv  automatik   diesel        jeep              nein
# 2   test  kleinwagen    manuell   benzin  volkswagen              nein
# 3   test  kleinwagen    manuell   diesel       skoda              nein
# 4   test   limousine    manuell   benzin         bmw                ja
#
#    yearOfRegistration  powerPS  kilometer  monthOfRegistration
# 0                1993        0     150000                    0
# 1                2004      163     125000                    8
# 2                2001       75     150000                    6
# 3                2008       69      90000                    7
# 4                1995      102     150000                   10

# %%
abtest_encoder = func_label_encoder(column=features["abtest"])
features["abtest"] = abtest_encoder.transform(features["abtest"])

# %%
def encode_all(column):
    encoder = func_label_encoder(features[column])
    features[column] = encoder.transform(features[column])

# %%
for column in categorical_data:
    encode_all(column=column)

# %%
features.head()
# Out:
#    abtest  vehicleType  gearbox  fuelType  brand  notRepairedDamage  \
# 0       1            6        1         1     38                  1
# 1       1            7        0         3     14                  1
# 2       1            4        1         1     38                  1
# 3       1            4        1         3     31                  1
# 4       1            6        1         1      2                  0
#
#    yearOfRegistration  powerPS  kilometer  monthOfRegistration
# 0                1993        0     150000                    0
# 1                2004      163     125000                    8
# 2                2001       75     150000                    6
# 3                2008       69      90000                    7
# 4                1995      102     150000                   10

# %%
features.corr()
# Out:
#                        abtest  vehicleType   gearbox  fuelType     brand  \
# abtest               1.000000     0.001751 -0.000252 -0.000092  0.002675
# vehicleType          0.001751     1.000000 -0.065079 -0.024672 -0.096037
# gearbox             -0.000252    -0.065079  1.000000 -0.149286  0.090916
# fuelType            -0.000092    -0.024672 -0.149286  1.000000 -0.044495
# brand                0.002675    -0.096037  0.090916 -0.044495  1.000000
# notRepairedDamage    0.000640     0.001107 -0.011972  0.022941  0.009299
# yearOfRegistration  -0.001380     0.108831 -0.022670  0.161355 -0.001622
# powerPS             -0.003174     0.035625 -0.299983  0.225539 -0.253994
# kilometer           -0.002141     0.043602 -0.018266  0.148395 -0.039902
# monthOfRegistration  0.000918    -0.037603 -0.045666  0.085097 -0.014939
#
#                      notRepairedDamage  yearOfRegistration   powerPS  \
# abtest                        0.000640           -0.001380 -0.003174
# vehicleType                   0.001107            0.108831  0.035625
# gearbox                      -0.011972           -0.022670 -0.299983
# fuelType                      0.022941            0.161355  0.225539
# brand                         0.009299           -0.001622 -0.253994
# notRepairedDamage             1.000000            0.090735  0.041102
# yearOfRegistration            0.090735            1.000000  0.066840
# powerPS                       0.041102            0.066840  1.000000
# kilometer                    -0.066062           -0.267503  0.102107
# monthOfRegistration           0.035042            0.021872  0.134087
#
#                      kilometer  monthOfRegistration
# abtest               -0.002141             0.000918
# vehicleType           0.043602            -0.037603
# gearbox              -0.018266            -0.045666
# fuelType              0.148395             0.085097
# brand                -0.039902            -0.014939
# notRepairedDamage    -0.066062             0.035042
# yearOfRegistration   -0.267503             0.021872
# powerPS               0.102107             0.134087
# kilometer             1.000000             0.002881
# monthOfRegistration   0.002881             1.000000

# %%
with_price = features.copy()
with_price["price"] = target
with_price.head()
# Out:
#    abtest  vehicleType  gearbox  fuelType  brand  notRepairedDamage  \
# 0       1            6        1         1     38                  1
# 1       1            7        0         3     14                  1
# 2       1            4        1         1     38                  1
# 3       1            4        1         3     31                  1
# 4       1            6        1         1      2                  0
#
#    yearOfRegistration  powerPS  kilometer  monthOfRegistration  price
# 0                1993        0     150000                    0    480
# 1                2004      163     125000                    8   9800
# 2                2001       75     150000                    6   1500
# 3                2008       69      90000                    7   3600
# 4                1995      102     150000                   10    650

# %%
with_price.corr()
# Out:
#                        abtest  vehicleType   gearbox  fuelType     brand  \
# abtest               1.000000     0.001751 -0.000252 -0.000092  0.002675
# vehicleType          0.001751     1.000000 -0.065079 -0.024672 -0.096037
# gearbox             -0.000252    -0.065079  1.000000 -0.149286  0.090916
# fuelType            -0.000092    -0.024672 -0.149286  1.000000 -0.044495
# brand                0.002675    -0.096037  0.090916 -0.044495  1.000000
# notRepairedDamage    0.000640     0.001107 -0.011972  0.022941  0.009299
# yearOfRegistration  -0.001380     0.108831 -0.022670  0.161355 -0.001622
# powerPS             -0.003174     0.035625 -0.299983  0.225539 -0.253994
# kilometer           -0.002141     0.043602 -0.018266  0.148395 -0.039902
# monthOfRegistration  0.000918    -0.037603 -0.045666  0.085097 -0.014939
# price               -0.001398    -0.049449 -0.209926  0.271940 -0.090958
#
#                      notRepairedDamage  yearOfRegistration   powerPS  \
# abtest                        0.000640           -0.001380 -0.003174
# vehicleType                   0.001107            0.108831  0.035625
# gearbox                      -0.011972           -0.022670 -0.299983
# fuelType                      0.022941            0.161355  0.225539
# brand                         0.009299           -0.001622 -0.253994
# notRepairedDamage             1.000000            0.090735  0.041102
# yearOfRegistration            0.090735            1.000000  0.066840
# powerPS                       0.041102            0.066840  1.000000
# kilometer                    -0.066062           -0.267503  0.102107
# monthOfRegistration           0.035042            0.021872  0.134087
# price                         0.191860            0.468082  0.451532
#
#                      kilometer  monthOfRegistration     price
# abtest               -0.002141             0.000918 -0.001398
# vehicleType           0.043602            -0.037603 -0.049449
# gearbox              -0.018266            -0.045666 -0.209926
# fuelType              0.148395             0.085097  0.271940
# brand                -0.039902            -0.014939 -0.090958
# notRepairedDamage    -0.066062             0.035042  0.191860
# yearOfRegistration   -0.267503             0.021872  0.468082
# powerPS               0.102107             0.134087  0.451532
# kilometer             1.000000             0.002881 -0.315932
# monthOfRegistration   0.002881             1.000000  0.116398
# price                -0.315932             0.116398  1.000000

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(with_price.corr(), cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
with_price.to_csv("G:/Data science/DS_ML_Project/datasets/preprocessed.csv", index=False)

# %% [markdown]
# # Features selection

# %%
import pandas as pd
preprocessed_data = pd.read_csv("G:/Data science/DS_ML_Project/datasets/preprocessed.csv")
preprocessed_data.head()
# Out:
#    abtest  vehicleType  gearbox  fuelType  brand  notRepairedDamage  \
# 0       1            6        1         1     38                  1
# 1       1            7        0         3     14                  1
# 2       1            4        1         1     38                  1
# 3       1            4        1         3     31                  1
# 4       1            6        1         1      2                  0
#
#    yearOfRegistration  powerPS  kilometer  monthOfRegistration  price
# 0                1993        0     150000                    0    480
# 1                2004      163     125000                    8   9800
# 2                2001       75     150000                    6   1500
# 3                2008       69      90000                    7   3600
# 4                1995      102     150000                   10    650

# %%
preprocessed_data.skew()
# Out:
# abtest                -0.072783
# vehicleType           -0.937901
# gearbox               -1.782140
# fuelType               1.555799
# brand                 -0.186167
# notRepairedDamage     -2.579732
# yearOfRegistration     0.283519
# powerPS               -0.020512
# kilometer             -1.849496
# monthOfRegistration    0.080546
# price                  1.306872
# dtype: float64

# %% [markdown]
# #### Log transformation of higher and lower skewness columns

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Assuming 'data' is your dataset

# Separate columns manually based on skewness
positively_skewed_cols = ['fuelType', 'notRepairedDamage', 'kilometer', 'price']
negatively_skewed_cols = ['gearbox']
symmetric_cols = ['abtest', 'vehicleType', 'brand', 'yearOfRegistration', 'powerPS', 'monthOfRegistration']

# Apply MinMaxScaler to positively skewed columns
min_max_scaler_pos = MinMaxScaler()
preprocessed_data[positively_skewed_cols] = min_max_scaler_pos.fit_transform(preprocessed_data[positively_skewed_cols])

# Apply StandardScaler to negatively skewed columns
standard_scaler_neg = StandardScaler()
preprocessed_data[negatively_skewed_cols] = standard_scaler_neg.fit_transform(preprocessed_data[negatively_skewed_cols])

# Apply StandardScaler to symmetric columns
standard_scaler_sym = StandardScaler()
preprocessed_data[symmetric_cols] = standard_scaler_sym.fit_transform(preprocessed_data[symmetric_cols])

# Now you have separate datasets with MinMaxScaler and StandardScaler applied to different groups of columns

# %%
preprocessed_data.head()
# Out:
#      abtest  vehicleType   gearbox  fuelType     brand  notRepairedDamage  \
# 0  0.964271     0.872648  0.448336  0.166667  1.278170                1.0
# 1  0.964271     1.479685 -2.230468  0.500000 -0.536386                1.0
# 2  0.964271    -0.341427  0.448336  0.166667  1.278170                1.0
# 3  0.964271    -0.341427  0.448336  0.500000  0.748924                1.0
# 4  0.964271     0.872648  0.448336  0.166667 -1.443665                0.0
#
#    yearOfRegistration   powerPS  kilometer  monthOfRegistration     price
# 0           -1.648547 -1.827888   1.000000            -1.532025  0.029502
# 1            0.093201  1.118330   0.827586             0.612013  0.602336
# 2           -0.381821 -0.472267   1.000000             0.076004  0.092194
# 3            0.726563 -0.580716   0.586207             0.344009  0.221266
# 4           -1.331866  0.015757   1.000000             1.148023  0.039951

# %%
target = preprocessed_data.price
preprocessed_data.drop("price", axis="columns", inplace=True)

# %%
features = preprocessed_data
features.head()
# Out:
#      abtest  vehicleType   gearbox  fuelType     brand  notRepairedDamage  \
# 0  0.964271     0.872648  0.448336  0.166667  1.278170                1.0
# 1  0.964271     1.479685 -2.230468  0.500000 -0.536386                1.0
# 2  0.964271    -0.341427  0.448336  0.166667  1.278170                1.0
# 3  0.964271    -0.341427  0.448336  0.500000  0.748924                1.0
# 4  0.964271     0.872648  0.448336  0.166667 -1.443665                0.0
#
#    yearOfRegistration   powerPS  kilometer  monthOfRegistration
# 0           -1.648547 -1.827888   1.000000            -1.532025
# 1            0.093201  1.118330   0.827586             0.612013
# 2           -0.381821 -0.472267   1.000000             0.076004
# 3            0.726563 -0.580716   0.586207             0.344009
# 4           -1.331866  0.015757   1.000000             1.148023

# %%
from sklearn.model_selection import train_test_split

# %%
X = features
y = target

# %%
X.shape, y.shape
# Out:
# ((330381, 10), (330381,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((264304, 10), (66077, 10), (264304,), (66077,))

# %% [markdown]
# # Modeling

# %% [markdown]
# #### Modeling using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 0.35978624,  0.26839319,  0.06080841, ..., -0.03702378,
#         0.37359419,  0.45609912])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_pred=y_pred, y_true=y_test)

# %%
r2
# Out:
# 0.5114324960060748

# %% [markdown]
# #### Using DecisionTreeRegressor Algorithm

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()

model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dec = model.predict(X_test)
y_pred_dec
# Out:
# array([0.14751076, 0.2335587 , 0.07044723, ..., 0.05347265, 0.3042102 ,
#        0.44864782])

# %%
r2 = r2_score(y_test, y_pred_dec)

# %%
r2
# Out:
# 0.7277702435905937

# %% [markdown]
# #### Using RandomForestRegressor Algorithm

# %%
from sklearn.ensemble import RandomForestRegressor


forest_model = RandomForestRegressor(max_depth=5)

forest_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5)

# %%
y_pred_forest = forest_model.predict(X_test)

# %%
r2 = r2_score(y_true=y_test, y_pred=y_pred_forest)
r2
# Out:
# 0.6718459652017097

# %% [markdown]
# # Cross validate model

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
import numpy as np
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 6)]
max_depth = [int(x) for x in np.linspace(start = 5, stop = 30, num = 4)]

# %%
random_grid = {
    'n_estimators' : n_estimators,
    'max_features': ['auto', 'sqrt'],
    'max_depth' : max_depth,
    'min_samples_split': [5, 10, 10, 100]
}

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor()

rf_random = RandomizedSearchCV(estimator = random_forest_model, param_distributions = random_grid, cv = 3, verbose = 2,
                  n_jobs = -1 )

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 15 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# g:\Data science\DS_ML_Project\env\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.81470562        nan        nan 0.81545167        nan
#  0.83717646 0.81546649        nan 0.81536594]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [5, 13, 21, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_split': [5, 10, 10, 100],
#                                         'n_estimators': [100, 320, 540, 760,
#                                                          980, 1200]},
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 320,
#  'min_samples_split': 5,
#  'max_features': 'sqrt',
#  'max_depth': 30}

# %%
predictions = rf_random.predict(X_test)

# %%
r2_score(y_test, predictions)
# Out:
# 0.8427523625172226

# %%
plt.figure(figsize=(10, 6))

# Plot the distribution of predicted values
sns.histplot(predictions, kde=True, color='blue', label='Predicted')

# Plot the distribution of true values
sns.histplot(y_test, kde=True, color='red', label='True')

# Add labels and title
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted and True Values')

# Add legend
plt.legend()

# Show the plot
plt.show()
